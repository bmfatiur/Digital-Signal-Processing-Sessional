# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(figsize= (12, 4))
t = np.arange(0, 4*np.pi, .001)
y = np.sin(t)**2 + np.cos(t)

plt.plot(t, y)
plt.title('sin^2(x) + cos(x)')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.grid()
plt.show()
